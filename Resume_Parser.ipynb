# %%
pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in c:\ananconda\lib\site-packages (0.11.8)
# Requirement already satisfied: pdfminer.six==20251107 in c:\ananconda\lib\site-packages (from pdfplumber) (20251107)
# Requirement already satisfied: Pillow>=9.1 in c:\ananconda\lib\site-packages (from pdfplumber) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\ananconda\lib\site-packages (from pdfplumber) (5.2.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\ananconda\lib\site-packages (from pdfminer.six==20251107->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\ananconda\lib\site-packages (from pdfminer.six==20251107->pdfplumber) (44.0.1)
# Requirement already satisfied: cffi>=1.12 in c:\ananconda\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\ananconda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Extract text from the Resume(pdf)

# %%
import pdfplumber

def extract_text(path):
    text = ""
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

# %% [markdown]
# ## Clean Extracted Text

# %%
import re

def clean_text(text):
    # Remove bullet symbols like \x7f
    text = re.sub(r'\x7f', ' ', text)
    
    # Replace newlines with space
    text = re.sub(r'\n', ' ', text)
    
    # Remove standalone numbers (list artifacts)
    text = re.sub(r'\b\d+\b', ' ', text)
    
    # Normalize all whitespace
    text = re.sub(r'\s+', ' ', text)
    
    return text.strip()

# %% [markdown]
# ## Extract Email & Number

# %%
def extract_email(text):
    emails= re.findall(r'\S+@+\S+', text)
    return emails[0] if emails else None
    

def extract_number(text):
    phone_pattern = r'(\+?\d{1,3}[-\s]?)?\d{5}[-\s]?\d{5}'
    phones = re.findall(phone_pattern, text)
    return phones[0] if phones else "Not found"

# %% [markdown]
# ## Extract Name

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
def extract_name(text):
    doc=nlp(text)
    for ent in doc.ents:
        if ent.label_=='PERSON':
            return ent.text
    return None

# %% [markdown]
# ## Extract Skills

# %%
def extract_skills(text):
    with open('skills.txt') as f:
        skills=[s.strip().lower() for s in f.readlines()]

    text=text.lower()
    return [skill for skill in skills if skill in text]

# %%
def resume_parser(path):
    text = extract_text(path)
    text = clean_text(text)

    return {
        "Name": extract_name(text),
        "Email": extract_email(text),
        "Phone": extract_number(text),
        "Skills": extract_skills(text),
    }

# %%
resume_parser('sample_resume_ml_training.pdf')
# Out:
# {'Name': 'John Doe Data',
#  'Email': 'johndoe@email.com',
#  'Phone': 'Not found',
#  'Skills': ['python', 'machine learning', 'sql', 'nlp']}
